# %% [markdown]
# # Project: Analyzing Macbeth
#
# ## Introduction
# Now we're going to do some rudimentry analysis of Shakespeare's classic play: Macbeth! You will get practice working with lists, condtionals and dictionaries, visualizing data, and thinking analytically about data.
#
# ## Objectives
# You will be able to:
# * Show mastery of the content covered in this section
#
# ## Getting the Data
# Here we start by importing a python package and using it to pull the transcript of Macbeth from the project Gutenberg website. We also preview a few details about what is now stored in the variable macbeth; it's a string with 119,846 characters, the first 500 of which are printed below.

# %%
import requests
macbeth = requests.get('https://www.gutenberg.org/files/1533/1533-0.txt').text

print(type(macbeth))
print(len(macbeth))
list_of_macbeth_words = macbeth.split(' ')
# Out:
# <class 'str'>
# 130737

# %%
len(list_of_macbeth_words)
# Out:
# 18195

# %%
len(list_of_macbeth_words)
unique_words = set(list_of_macbeth_words)
len(unique_words)
# Out:
# 7121

# %%
import pandas as pd

# %% [markdown]
# ## Your Task
#
# Your task is to create a bar graph of the 25 most common words in Shakespeare's Macbeth.
#
#
# A common python programming pattern to counting objects, produce histograms, or update statistics is to make calls to a dictionary as you iterate through a list. For example, given a list of words, you can create a dictionary to store counts and then iterate through the list of words, checking how many times each word has appeared using your dictionary, and updating the dictionary count now that you've seen that word again. The `dictionary.get()` method is very useful in doing this. Read the docstring for the dictionary.get() method and use it along with the pseudocode above to create a bar graph of the 25 most common words from the transcript of Macbeth which has been loaded into a variable 'Macbeth'. Be sure to include a title and appropriate labels for your graph.

# %%
from collections import Counter

# %%
# Your code here\
# Pseudo-code Outline
# Split the transcript into words

mdict = Counter(unique_words_2)

# [[x, list_of_macbeth_words.count(x)] for x in unique_wordsa]

# Create a dictionary
# Iterate through the text of Macbeth
# Update word counts
# Create Bar Graph
# Include descriptive titles and labels

# %%
d = dict(mdict)

# %%
d['Project']
# Out:
# 61

# %%
df = pd.DataFrame.from_dict(d, orient='index')

# %%
df[0].sort_values(ascending=False)
# Out:
# I               208
# Enter            65
# Project          61
# thou             59
# The              50
#                ...
# cease,            1
# climb             1
# upward\r\nTo      1
# before.âMy      1
# trenched          1
# Name: 0, Length: 7007, dtype: int64

# %%
import nltk
from nltk.corpus import stopwords

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /home/effulgent-
# [nltk_data]     block-4530/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
stopwords.words('english')
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
# ...

# %%
df[0].max()
# Out:
# 719

# %%
pd.set_option('display.max_rows', 100)

# %%
df[0].sort_values(ascending=False)
# Out:
# the              719
# and              464
# of               433
# to               367
# a                266
#                 ...
# wren,\r\nThe       1
# diminutive         1
# birds,             1
# fight,\r\nHer      1
# speaks             1
# Name: 0, Length: 7121, dtype: int64

# %%
import io 
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize

# %%
#word_tokenize accepts a string as an input, not a file. 
stop_words = set(stopwords.words('english'))

# %%
unique_words_2 = []

# %%
# words = line.split() 
for i in list_of_macbeth_words: 
    if not i in stop_words: 
        unique_words_2.append(i)

# %%
unique_words_2
# Out:
# ['Project',
#  'Gutenbergâ\x80\x99s',
#  'Macbeth,',
#  'William',
#  'Shakespeare\r\n\r\nThis',
#  'eBook',
#  'use',
#  'anyone',
#  'anywhere',
#  'United',
#  'States',
#  'and\r\nmost',
#  'parts',
#  'world',
#  'cost',
#  'almost',
#  'restrictions\r\nwhatsoever.',
#  'You',
#  'may',
#  'copy',
#  'it,',
#  'give',
#  'away',
#  're-use',
#  'terms\r\nof',
#  'Project',
#  'Gutenberg',
#  'License',
#  'included',
#  'eBook',
#  'online',
#  'at\r\nwww.gutenberg.org.',
#  'If',
#  'located',
#  'United',
#  'States,',
#  'youâ\x80\x99ll\r\nhave',
#  'check',
#  'laws',
#  'country',
#  'located',
#  'using\r\nthis',
#  'ebook.\r\n\r\n\r\n\r\nTitle:',
#  'Macbeth\r\n\r\nAuthor:',
#  'William',
#  'Shakespeare\r\n\r\nRelease',
#  'Date:',
#  'November,',
#  '1998',
#  '[Etext',
#  '#1533]\r\nLast',
#  'Updated:',
#  'February',
#  '28,',
#  '2019\r\n\r\nLanguage:',
#  'English\r\n\r\nCharacter',
#  'set',
#  'encoding:',
#  'UTF-8\r\n\r\n***',
#  'START',
#  'OF',
#  'THIS',
# ...

# %%
unique_words_2

# %%
unique_words = set(unique_words_2)

# %%
len(list_of_macbeth_words)
unique_words = set(list_of_macbeth_words)
len(unique_words)

# %%
len(unique_words)
# Out:
# 7007

# %%
mdict
# Out:
# Counter({'Project': 61,
#          'Gutenbergâ\x80\x99s': 1,
#          'Macbeth,': 13,
#          'by': 60,
#          'William': 4,
#          'Shakespeare\r\n\r\nThis': 1,
#          'eBook': 4,
#          'is': 177,
#          'for': 94,
#          'the': 719,
#          'use': 10,
#          'of': 433,
#          'anyone': 3,
#          'anywhere': 2,
#          'in': 242,
#          'United': 11,
#          'States': 6,
#          'and\r\nmost': 1,
#          'other': 16,
#          'parts': 2,
#          'world': 3,
#          'at': 53,
#          'no': 53,
#          'cost': 2,
#          'and': 464,
#          'with': 171,
#          'almost': 7,
#          'restrictions\r\nwhatsoever.': 1,
#          'You': 17,
#          'may': 38,
#          'copy': 8,
#          'it,': 14,
#          'give': 13,
#          'it': 109,
#          'away': 6,
#          'or': 89,
#          're-use': 2,
#          'under': 10,
#          'terms\r\nof': 1,
#          'Gutenberg': 19,
# ...

# %%
df2 = df.nlargest(50,0)

# %%
df2.reset_index(inplace=True)

# %%
df2.hist(bins=50)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f60fb9eacc0>]],
#       dtype=object)

# %%
counts = pd.DataFrame.from_dict(mdict, orient='index')

# %%
counts = counts.sort_values(by=counts.columns[0], ascending=False)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
words = macbeth.split()

# %%
new_words =[]

# %%
# words = line.split() 
for i in words: 
    if not i in stop_words: 
        new_words.append(i)

# %%
# Out:
# list

# %%
# Create a dictionary
word_counts = {}
# Iterate through the text of Macbeth
for word in words:
    # Update word counts
    word_counts[word] = word_counts.get(word, 0) + 1 #Get previous entry, update by 1

# %%
counts.head(25).plot(kind='barh')
plt.title('Top 25 Words from Macbeth')
plt.ylabel('Word')
plt.xlabel('Number of Occurences')
# Include descriptive titles and labels
# Out:
# Text(0.5, 0, 'Number of Occurences')

# %% [markdown]
# ## Level Up (Optional)
# This project should take you about an hour and a half to complete. If you're done much more quickly than that and are not behind in the course, feel free to deepen your knowledge by completing any or all of the following tasks until you run out of time:
# * Create a list of top characters by mentions of their names
# * Split the text by which character is talking
# * Create subgraphs of the most common words by character
# * Reduce the string to the text of the play itself. (Remove any initial notes, forward, introduction, appendix, etc.)
# * Come up with some other fun analyses of the text!
#
# ## Summary
# Congratulations! You've got some extra practice combining various data types into useful programming patterns and done an initial analysis of a classic text!
